# %%
from google.colab import drive
drive.mount('/content/drive')

import os

URL_FILE = input("Inserire URL...")
CARTELLA_DRIVE = "Downloads"
path_completo = f"/content/drive/My Drive/{CARTELLA_DRIVE}"
if not os.path.exists(path_completo):
    os.makedirs(path_completo)
    print(f"📂 Cartella '{CARTELLA_DRIVE}' creata con successo.")

print(f"Inizio download in: {path_completo}")
print("⏳ Attendere prego...")
# !wget -P "{path_completo}" "{URL_FILE}"

print("\n✅ Download completato! Verifica nel tuo Google Drive.")
